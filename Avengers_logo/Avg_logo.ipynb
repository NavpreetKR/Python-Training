# %%
import PIL
import numpy as np
import matplotlib.pyplot as plt
avlg_pil = PIL.Image.open("avlg.png")
avlg_np = np.array(avlg_pil)
avlg_np.shape
# Out:
# (1600, 1376, 4)

# %%
av_pil = PIL.Image.open("avg.jpg")
av_np = np.array(av_pil)
plt.imshow(avlg_np)

# %%
short = avlg_np[::12,::10].copy()

# %%
plt.imshow(short)

# %%
plt.imshow(av_np)

# %%
w = avlg_np.shape[1]
h = avlg_np.shape[0]
x = 1200
y = 50

# %%
cut = av_np[y:y+150,x:x+w]

# %%
plt.imshow(cut)

# %%
for row in range(short.shape[0]):
    for col in range(short.shape[1]):
        if short[row, col, 3] < 100:
            cut[row, col] = avlg_np[row, col, :3]

# %%
plt.imshow(av_np)

# %%
f = open("AVG_logo.png", "wb")
img = PIL.Image.fromarray(av_np)
img.save(f)
