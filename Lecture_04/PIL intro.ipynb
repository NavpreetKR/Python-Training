# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img = np.zeros((100,100,3), dtype=np.uint8)

# %%
plt.imshow(img)

# %%
img[:30, :, 0]= 255

# %%
plt.imshow(img)

# %%
img[30:60, :, 1]= 255
plt.imshow(img)

# %%
img[60:, :, 2]= 255
plt.imshow(img)

# %%
img[30:60, :, 0]= 255
plt.imshow(img)

# %%
img[60:, :, 0]= 255
plt.imshow(img)

# %%
import PIL

# %%
 b = PIL.Image.open("../Lecture_01/cupcake.jpg")

# %%
type(b)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
b
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=495x741 at 0x14C89D29978>

# %%
meth = np.array(b)

# %%
type(meth)
# Out:
# numpy.ndarray

# %%
meth.shape
# Out:
# (741, 495, 3)

# %%
meth.dtype
# Out:
# dtype('uint8')

# %%
plt.imshow(b)

# %%
short = meth[::2,::2].copy()
plt.imshow(short)

# %%
short[:,:,0] = 0   #removed red from rgb
plt.imshow(short)

# %%
img = PIL.Image.fromarray(short)
f = open("myedit.jpg","wb")
img.save(f)
