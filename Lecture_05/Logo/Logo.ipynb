# %%
import numpy as np
import matplotlib.pyplot as plt
import PIL

# %%
cb_pil = PIL.Image.open("cb.png")

# %%
cb_np = np.array(cb_pil)

# %%
cb_np.shape
# Out:
# (189, 454, 4)

# %%
cup_pil = PIL.Image.open("cupcake.jpg")

# %%
cup_np = np.array(cup_pil)

# %%
plt.imshow(cb_np[:,:,3], cmap="gray")  #the pixels where alpha = 255

# %%
cut = cup_np[:cb_np.shape[0],-cb_np.shape[1]:]

# %%
plt.imshow(cut)

# %%
for row in range(cb_np.shape[0]):
    for col in range(cb_np.shape[1]):
        if cb_np[row, col, 3] > 100:
            cut[row, col] = cb_np[row, col, :3] #3 cause we r pasting a 4 layered pic on 
                                                    #3 layered one

# %%
plt.imshow(cup_np)

# %%
f = open("cupcake_logo.png", "wb")
img = PIL.Image.fromarray(cup_np)
img.save(f)
